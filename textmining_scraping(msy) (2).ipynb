# %%
import requests
import time
import math
import numpy as np
from bs4 import BeautifulSoup
import re

# %%
# 로그인을 위해 세션 불러오기
session=requests.session()

url = "https://www.jobplanet.co.kr/users/sign_in?_nav=gb"
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'
headers = {'Content-type': 'application/json', 'Accept': 'text/plain', 'User-Agent':user_agent}
login_data = {'user':{'email':'selina1031@hanyang.ac.kr', 'password':'Qwertyui1@', 'remember_me':'true'}}
session = requests.session()

login_response = session.post(url, json = login_data, headers = headers)

# %%
#스크래핑

category=[707,704]
scraping_result=[]
#들어가야할것 : 평점, 리뷰. 다만 10개씩 잘라서 동일 간격으로 30번만 반복
# txtlink_page, txt1(별점), us_label(한줄평)
#동일 페이지 간격으로 총 300개 내외의 리뷰를 뽑아내기 위해 리뷰 총 개수 구하기

for i in category:
  time.sleep(0.5)
  url="https://www.jobplanet.co.kr/reviews?&industry_id="+str(i)
  response=session.get(url)
  soup=BeautifulSoup(response.text,'html.parser')
  review=soup.find('span', class_='num')
  review=int(review.get_text())
  page=math.floor(review/10)+1
  page_count=math.floor(review/300)
  
  print(review) #리뷰총개수
  print(page) #페이지 수
  print(page_count) #읽어올 페이지 간격
  
  #리뷰 스크래핑  
  for j in range(1,page,page_count):
    time.sleep(0.5)
    url="https://www.jobplanet.co.kr/reviews?&industry_id="+str(i)+"&page="+str(j)
    response=session.get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    point_label=soup.find_all('dd',class_='txt1')
    review_label=soup.find_all('h2',class_='us_label')

    #파싱 및 리스트 저장(2차원 배열)
    for m, n in zip(point_label, review_label):
      scraping_result.append([i,m.get_text(),n.get_text().replace('BEST','')])

#페이지가 끝나 불러오기 오류가 나는 경우 예외 처리
#    try:
#      driver.find_element_by_css_selector("a.btn_pgnext").click()
#      time.sleep(1)
#    except:
#      pass
# Out:
# 3736
# 374
# 12
# 342
# 35
# 1

# %%
len(scraping_result)
# Out:
# 660

# %%
scraping_result[:50]
# Out:
# [[707, '5.0', '"1년 뒤,  5년 뒤, 10년 뒤가 더 기대되는 미친성장속도의 회사"'],
#  [707,
#   '5.0',
#   '"대표님의 마인드, 일처리 방식 모든게 부족하지 않았었습니다. 설계 프로그램에 대해서 상세히 배워볼 수 있었고 다양한 프로그램을 익힐 수 있었습니다."'],
#  [707,
#   '5.0',
#   '"우리나라 최고 의류 도매 시장에서 IT 서비스를 제공한다는 입지적인 커리어를 쌓을 수 있는 곳. 회사 대표가 한국 의류 도매 시장에서 매우 입지적인 인물이면서 매우 지속가능한 방향으로 사업을 운영하기 때문에 회사가 더 유명해지기 전에 센스있는 IT 부문 인재들이 들어오면 좋을 곳"'],
#  [707, '5.0', '"사업적인 역량을 보고 배우며 습득하기에 매우 훌륭합니다."'],
#  [707,
#   '5.0',
#   '"한국에서는 보기 드문 기업입니다. C-Level에서 적극적인 지원과 체계 구축을 위해 힘을 쓰고 있습니다. 업무적으로나, 복지적으로나 한국에서는 원탑입니다."'],
#  [707, '5.0', '"꾸준히 성장중인 기업, 발전 가능성이 높은 빅데이터 및 보안 플랫폼 사업, 민주적이고 건강한 기업 문화"'],
#  [707,
#   '5.0',
#   '"회사 분위기는 수평적으로, 업무는 프로페셔널하게!\r빠르게 성장하고 있으며, 회사 경영, 영업 상황을 매주 투명하게 공유!\r 성장하는 모습이 눈에 보여 즐거운 회사"'],
#  [707, '5.0', '"직원이 우선이 되는 최고의 환경의 회사"'],
#  [707, '5.0', '"발전 가능성이 크고 사람 스트레스 없는 자유로운 회사입니다."'],
#  [707, '5.0', '"이곳에서 일하면 해보고싶은 거 해볼수있고 자기도 능력치가 쌓임"'],
#  [707, '4.3', '"자유롭게 근무를 하고 맡은 일만 해도 되는 야근이 업는 회사"'],
#  [707, '4.3', '"일은 어렵지 않고 수월하고 전반적인 팀 분위기가 나쁘지 않았음"'],
#  [707, '4.3', '"빠른 승진, 확실한 연봉인상, 자유로운 회사 분위기, 탄력근무제, 프리덤"'],
#  [707, '4.3', '"GS 홈쇼핑 협력사. 거의 고객사에 의존하고 있는 구조임"'],
#  [707, '4.3', '"다양한 아이디어회의와 직원화합을 우선으로 하는 분위기가 좋았어요."'],
#  [707, '4.3', '"많은 것을 배울 수 있는 곳.\r자유로운 기업 문화"'],
#  [707, '4.3', '"개발자가 대우받으며 보람차게 일할 수 있는 곳"'],
#  [707, '4.3', '"성과를 잘 내는 사람에겐 추천하고 싶은 기업."'],
#  [707, '4.3', '"점차 커가는 회사 대표가 직원들의 이야기를 듣고 반영하러고함"'],
#  [707, '4.3', '"다양한 사업 분야를 많이 배울 수 있습니다."'],
#  [707, '4.0', '"기업문화가 선진적인 느낌. 아는 사람들만 아는 기업이라지만 아는 사람들은 인정할 수 밖에 없는 기업."'],
#  [707,
#   '3.9',
#   '"회사와 사람이 함께 성장할 수 있도록 전폭적인 지원을 아끼지 않는 곳.\r그리고 서비스만큼이나 내부 직원들을 정말 소중하게 여기는 곳."'],
#  [707,
#   '3.9',
#   '"번지르르한 겉모습과 좋은 동료 직원들에 비해 내부시스템이 최악이었던 너무 아쉬운 회사.평점에 속아 입사하는 실수를 하지 않길.."'],
#  [707, '3.9', '"인성을 중요시하여 좋은 사람들만 모여있고 다양한 업무 경험을 할 수 있는 회사"'],
#  [707,
#   '3.9',
#   '"증권시장이 전산적으로 어떻게 구성되어 있고 거래가 어떤 방법으로 이루어지는 배울 수 잇는 소중한 기회가 되었고 특히 세계 표준으로 사용하는 FIX 엔진 기반의 시스템으로 국내 주문시장 점유율 1위에 걸맞는 안정된 수입원을 바탕으로 새로운 상품 개발에 힘쓰며 직원 근무 여건과 복지에도 큰 관심을 가진 회사"'],
#  [707, '3.9', '"군대분위기가 있으나 대체로 근무환경이 좋고 페이도 업계 상위 수준임"'],
#  [707, '3.9', '"분위기는 좋은 회사지만 발전가능성은 적은 회사좋은 동료들과 일할 수는 있지만 커리어는 포기해야함"'],
#  [707, '3.9', '"인테리어 쪽 사업이라 다양한 기술들을 접할 수 있는 스타트업."'],
#  [707, '3.9', '"개발자가 대우받으며 일할 수 있는 곳"'],
#  [707, '3.9', '"OS 설치에 흥미가 있으시다면 추천."'],
#  [707, '3.7', '"자유로운 근무환경, 직원들의 작업방식을 존중해주는 회사"'],
#  [707, '3.7', '"오래된 중소기업으로 사무실 환경은 직원이 많지 않아 조용한 분위기의 평범한 일반 사무실"'],
#  [707,
#   '3.7',
#   '"임원진이 직원들을 무시하고 회의하다 욕을하고 일을 잘해도 못해도 직원들은 욕먹는 회사. 직원들의 발전은 커녕 기를 죽이기 쉽상이다."'],
#  [707, '3.7', '"국내 회계 프로그램을 거의 독점하고있고 해외로의 진출도 많이 하고 있어 기대는 되지만 급여가 보통임"'],
#  [707, '3.7', '"스타트업이라 그런지 여러 일들을 경험할 수 있지만 체계는 부족한듯..."'],
#  [707,
#   '3.7',
#   '"구축팀 백엔드/프론트 팀장들이 실력이 좋다. 바쁜 시간쪼개서 리뷰도 해주려고 하고 실력 쌓고싶은 개발자들에게는 추천"'],
#  [707, '3.7', '"광고의 모든면을 접할수있었던 기업으로 광고인으로서 성장하게 되었다"'],
#  [707, '3.7', '"회사의 미래에 대해서는 일하는 사람 입장에서 확신을 갖기 힘든 회사."'],
#  [707,
#   '3.7',
#   '"회사 내 분위기가 좋다. 수평적이고, 경영진도 직원들이 일하기 좋은 방향으로 개선하려고 노력하는 부분들이 보인다. 매출도 잘 나오고 있고, 기술력이 있어서 앞으로가 기대되는 회사이다."'],
#  [707,
#   '3.7',
#   '"개발자로써 좋은 기술력을 경험해볼 수 있음. DDD와 그외 아키텍처에 다한 부분 비즈니스에 대한 부분 다양한 경험이 커리어에 충분히 도움될것임"'],
#  [707, '3.5', '"개발환경 우수하여 근무에 좋은 환경이에요.\r좋은 마인드"'],
#  [707, '3.5', '"개발자 중심의 회사여서 개발자에겐 좋을수도 나쁠수도 있는 양날의 검 같은 회사"'],
#  [707, '3.5', '"자유롭게 개발할수 있는곳. 자유로운 회의를 통해 직급관계없이 회의 참여가 가능함."'],
#  [707,
#   '3.5',
#   '"줄줄이 퇴사. 고인물 물갈이하는것도 아니고 너무하다고 생각함..사람으로 돌아가던 회사인데 그 사람들이 다 나가고 남은 사람들은 고통받는 중"'],
#  [707, '3.5', '"증권관련하여 다양한 경험을 해볼 수 있는 곳경력직이 다니기에 좋다"'],
#  [707, '3.5', '"대형통신사와 협업하는 회사업종성격상 젊고 편안한 회사분위기"'],
#  [707, '3.5', '"소프트웨어 영업을 직접 발로 뛰며 몸으로 습득할 수 있음"'],
#  [707, '3.5', '"직원들을 신뢰하며 다양한 아이디어를 추구를 존중하는 기술회사"'],
#  [707, '3.5', '"워라밸은 어느정도 가능\r회사 유지는 꾸준히 가능하나 발전 가능성은 적어보임"'],
#  [707, '3.5', '"실력이 어느정도있다면 훌륭한 대접을 받을수 있다.사내 분위기는 개인적으로 재직했던곳중 최고"']]
